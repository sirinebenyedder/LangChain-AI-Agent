# %% [markdown]
# <a href="https://colab.research.google.com/github/sirinebenyedder/LangChain-AI-Agent/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clone the repository
import os
repo_url = "https://github.com/sirinebenyedder/LangChain-AI-Agent.git"
repo_name = "LangChain-AI-Agent"

if not os.path.exists(repo_name):
    # !git clone {repo_url}
    # %cd {repo_name}
else:
    # %cd /content/{repo_name}
    # !git pull

# 2. Install dependencies
# !pip install -r requirements.txt -q
print("✅ Environment Ready!")

# %%
import getpass
# Use YOUR own Gemini Key
print("--- ParaMaster AI Authentication ---")
MY_KEY = getpass.getpass("Enter your Gemini API Key: ")
# Out:
# --- ParaMaster AI Authentication ---

# %%
from app import launch_app

# 3. Launch the Gradio Interface
print("🚀 Starting ParaMaster...")
launch_app(MY_KEY)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from app import launch_app
#       3 # 3. Launch the Gradio Interface
#       4 print("🚀 Starting ParaMaster...")
#
# File c:\Users\hp\Desktop\LangChain-AI-Agent\app.py:1
# ----> 1 import gradio as gr
#       2 from tools.pedagogy import get_learning_tools
#       4 def launch_app(api_key):
#
# ModuleNotFoundError: No module named 'gradio'
